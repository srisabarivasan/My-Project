# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales=pd.read_csv('sales_data.csv')

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# ...

# %%
sales.head(2)
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category Sub_Category  \
# 0  Canada  British Columbia      Accessories   Bike Racks
# 1  Canada  British Columbia      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit   Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0  360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0  360.0
#
#    Revenue
# 0    950.0
# 1    950.0

# %%
sales.tail()
# Out:
#             Date  Day Month  Year  Customer_Age             Age_Group  \
# 7638  2016-05-03    3   May  2016            29  Young Adults (25-34)
# 7639  2016-05-03    3   May  2016            29  Young Adults (25-34)
# 7640  2014-06-07    7  June  2014            29  Young Adults (25-34)
# 7641  2014-06-07    7  June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7  June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country    State Product_Category  \
# 7638               F  United Kingdom  England      Accessories
# 7639               F  United Kingdom  England      Accessories
# 7640               F  United Kingdom  England      Accessories
# 7641               F  United Kingdom  England      Accessories
# 7642               F  United Kingdom  England      Accessories
#
#            Sub_Category                Product  Order_Quantity  Unit_Cost  \
# 7638  Bottles and Cages  Water Bottle - 30 oz.             6.0        2.0
# ...

# %%
sales.tail(2)
# Out:
#             Date  Day Month  Year  Customer_Age             Age_Group  \
# 7641  2014-06-07    7  June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7  June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country    State Product_Category  \
# 7641               F  United Kingdom  England      Accessories
# 7642               F  United Kingdom  England      Accessories
#
#            Sub_Category                Product  Order_Quantity  Unit_Cost  \
# 7641  Bottles and Cages  Water Bottle - 30 oz.            18.0        2.0
# 7642  Bottles and Cages    Water Bottle - 30 o             NaN        NaN
#
#       Unit_Price  Profit  Cost  Revenue
# 7641         5.0    50.0  36.0     86.0
# 7642         NaN     NaN   NaN      NaN

# %%
sales['Customer_Age']
# Out:
# 0       19
# 1       19
# 2       49
# 3       49
# 4       47
#         ..
# 7638    29
# 7639    29
# 7640    29
# 7641    29
# 7642    29
# Name: Customer_Age, Length: 7643, dtype: int64

# %%
sales.loc[0]
# Out:
# Date                         2013-11-26
# Day                                  26
# Month                          November
# Year                               2013
# Customer_Age                         19
# Age_Group                   Youth (<25)
# Customer_Gender                       M
# Country                          Canada
# State                  British Columbia
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                      8.0
# Unit_Cost                          45.0
# Unit_Price                        120.0
# Profit                            590.0
# Cost                              360.0
# Revenue                           950.0
# Name: 0, dtype: object

# %%
sales.loc[[0,1]]
# Out:
#          Date  Day     Month  Year  Customer_Age    Age_Group Customer_Gender  \
# 0  2013-11-26   26  November  2013            19  Youth (<25)               M
# 1  2015-11-26   26  November  2015            19  Youth (<25)               M
#
#   Country             State Product_Category Sub_Category  \
# 0  Canada  British Columbia      Accessories   Bike Racks
# 1  Canada  British Columbia      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit   Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0  360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0  360.0
#
#    Revenue
# 0    950.0
# 1    950.0

# %%
sales.iloc[0:3]
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 2  Hitch Rack - 4-Bike            23.0       45.0       120.0  1366.0  1035.0
#
#    Revenue
# 0    950.0
# 1    950.0
# 2   2401.0

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
sales.shape
# Out:
# (7643, 18)

# %%
sales.shape[0]
# Out:
# 7643

# %%
sales.shape[1]
# Out:
# 18

# %%
sales.State=='California'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7638    False
# 7639    False
# 7640    False
# 7641    False
# 7642    False
# Name: State, Length: 7643, dtype: bool

# %%
sales[sales.State=='California']
# Out:
#             Date  Day   Month  Year  Customer_Age             Age_Group  \
# 38    2013-07-13   13    July  2013            43        Adults (35-64)
# 39    2015-07-13   13    July  2015            43        Adults (35-64)
# 40    2014-03-31   31   March  2014            43        Adults (35-64)
# 41    2016-03-31   31   March  2016            43        Adults (35-64)
# 42    2013-08-28   28  August  2013            61        Adults (35-64)
# ...          ...  ...     ...   ...           ...                   ...
# 7369  2016-06-24   24    June  2016            25  Young Adults (25-34)
# 7370  2014-06-26   26    June  2014            25  Young Adults (25-34)
# 7371  2016-06-26   26    June  2016            25  Young Adults (25-34)
# 7372  2014-07-26   26    July  2014            25  Young Adults (25-34)
# 7373  2016-07-26   26    July  2016            25  Young Adults (25-34)
#
#      Customer_Gender        Country       State Product_Category  \
# ...

# %%
s=sales.State
s.value_counts()
# Out:
# State
# California             1346
# British Columbia       1282
# England                1067
# Washington              742
# New South Wales         470
# Oregon                  386
# Victoria                314
# Queensland              276
# Nordrhein-Westfalen     186
# Seine Saint Denis       170
# Saarland                166
# Hessen                  146
# Seine (Paris)           146
# Hamburg                 142
# Bayern                  124
# Essonne                 102
# Nord                     94
# South Australia          88
# Hauts de Seine           64
# Yveline                  58
# Loiret                   42
# Tasmania                 38
# Seine et Marne           36
# Moselle                  22
# Val de Marne             20
# Val d'Oise               18
# Garonne (Haute)          16
# Charente-Maritime        12
# Brandenburg              12
# Loir et Cher             10
# Somme                     8
# Alberta                   8
# Pas de Calais             8
# ...

# %%
sales['Cost'].mean()
# Out:
# 79.91625228997644

# %%
sales['Cost'].mean().round(5)
# Out:
# 79.91625

# %%
sales['Profit'].median()
# Out:
# 53.0

# %%
sales['Profit'].mode()
# Out:
# 0    6.0
# Name: Profit, dtype: float64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7643 entries, 0 to 7642
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7643 non-null   object
#  1   Day               7643 non-null   int64
#  2   Month             7643 non-null   object
#  3   Year              7643 non-null   int64
#  4   Customer_Age      7643 non-null   int64
#  5   Age_Group         7643 non-null   object
#  6   Customer_Gender   7643 non-null   object
#  7   Country           7643 non-null   object
#  8   State             7643 non-null   object
#  9   Product_Category  7643 non-null   object
#  10  Sub_Category      7643 non-null   object
#  11  Product           7643 non-null   object
#  12  Order_Quantity    7642 non-null   float64
#  13  Unit_Cost         7642 non-null   float64
#  14  Unit_Price        7642 non-null   float64
#  15  Profit            7642 non-null   float64
# ...

# %%
sales.describe()
# Out:
#                Day         Year  Customer_Age  Order_Quantity    Unit_Cost  \
# count  7643.000000  7643.000000   7643.000000     7642.000000  7642.000000
# mean     15.403768  2014.588774     36.141437       14.035593     9.193405
# std       8.880167     1.114518     11.007290        8.832830    16.896570
# min       1.000000  2013.000000     17.000000        1.000000     2.000000
# 25%       8.000000  2014.000000     28.000000        6.000000     2.000000
# 50%      15.000000  2014.000000     35.000000       13.000000     2.000000
# 75%      23.000000  2016.000000     43.000000       22.000000     4.000000
# max      31.000000  2016.000000     87.000000       32.000000    59.000000
#
#         Unit_Price       Profit         Cost      Revenue
# count  7642.000000  7642.000000  7642.000000  7642.000000
# mean     24.408794   111.172075    79.916252   191.088328
# std      45.430637   207.095020   141.869081   347.815830
# min       5.000000     2.000000     2.000000     4.000000
# ...

# %%
sales['Profit'].max()
# Out:
# 2214.0

# %%
sales['Profit'].min()
# Out:
# 2.0

# %%
sales['Profit'].sum()
# Out:
# 849577.0

# %%
sales.sort_values(by=['Profit','Cost'])
# Out:
#             Date  Day      Month  Year  Customer_Age             Age_Group  \
# 1142  2015-07-29   29       July  2015            40        Adults (35-64)
# 1159  2015-10-22   22    October  2015            22           Youth (<25)
# 1195  2014-04-24   24      April  2014            42        Adults (35-64)
# 1523  2013-09-13   13  September  2013            33  Young Adults (25-34)
# 1645  2014-03-04    4      March  2014            28  Young Adults (25-34)
# ...          ...  ...        ...   ...           ...                   ...
# 244   2014-01-07    7    January  2014            31  Young Adults (25-34)
# 90    2014-02-12   12   February  2014            46        Adults (35-64)
# 182   2014-01-17   17    January  2014            53        Adults (35-64)
# 245   2016-01-07    7    January  2016            31  Young Adults (25-34)
# 7642  2016-06-07    7       June  2016            29  Young Adults (25-34)
#
# ...

# %%
sales.sort_values(by=['Profit'])
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 1780  2016-03-12   12     March  2016            34  Young Adults (25-34)
# 6707  2016-03-25   25     March  2016            44        Adults (35-64)
# 3669  2016-01-08    8   January  2016            53        Adults (35-64)
# 7395  2016-03-02    2     March  2016            33  Young Adults (25-34)
# 1142  2015-07-29   29      July  2015            40        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 244   2014-01-07    7   January  2014            31  Young Adults (25-34)
# 90    2014-02-12   12  February  2014            46        Adults (35-64)
# 182   2014-01-17   17   January  2014            53        Adults (35-64)
# 245   2016-01-07    7   January  2016            31  Young Adults (25-34)
# 7642  2016-06-07    7      June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
sales.isnull()
# Out:
#        Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0     False  False  False  False         False      False            False
# 1     False  False  False  False         False      False            False
# 2     False  False  False  False         False      False            False
# 3     False  False  False  False         False      False            False
# 4     False  False  False  False         False      False            False
# ...     ...    ...    ...    ...           ...        ...              ...
# 7638  False  False  False  False         False      False            False
# 7639  False  False  False  False         False      False            False
# 7640  False  False  False  False         False      False            False
# 7641  False  False  False  False         False      False            False
# 7642  False  False  False  False         False      False            False
#
# ...

# %%
sales.notnull()
# Out:
#       Date   Day  Month  Year  Customer_Age  Age_Group  Customer_Gender  \
# 0     True  True   True  True          True       True             True
# 1     True  True   True  True          True       True             True
# 2     True  True   True  True          True       True             True
# 3     True  True   True  True          True       True             True
# 4     True  True   True  True          True       True             True
# ...    ...   ...    ...   ...           ...        ...              ...
# 7638  True  True   True  True          True       True             True
# 7639  True  True   True  True          True       True             True
# 7640  True  True   True  True          True       True             True
# 7641  True  True   True  True          True       True             True
# 7642  True  True   True  True          True       True             True
#
#       Country  State  Product_Category  Sub_Category  Product  Order_Quantity  \
# ...

# %%
sales.size
# Out:
# 137574

# %%
size=sales.size
print("sales={}".format(size))
# Out:
# sales=137574

# %%
sales.ndim
# Out:
# 2

# %%
s.ndim
# Out:
# 1

# %%
sales["Country"].str.lower()
sales
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26  November  2013            19           Youth (<25)
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 2     2014-03-23   23     March  2014            49        Adults (35-64)
# 3     2016-03-23   23     March  2016            49        Adults (35-64)
# 4     2014-05-15   15       May  2014            47        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 7638  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7639  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7640  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7641  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7      June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales['Country']=sales["Country"].str.upper()
sales
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26  November  2013            19           Youth (<25)
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 2     2014-03-23   23     March  2014            49        Adults (35-64)
# 3     2016-03-23   23     March  2016            49        Adults (35-64)
# 4     2014-05-15   15       May  2014            47        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 7638  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7639  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7640  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7641  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7      June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales['Country']=sales["Country"].str.upper().str.title()
sales
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26  November  2013            19           Youth (<25)
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 2     2014-03-23   23     March  2014            49        Adults (35-64)
# 3     2016-03-23   23     March  2016            49        Adults (35-64)
# 4     2014-05-15   15       May  2014            47        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 7638  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7639  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7640  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7641  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7      June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales['Year'].unique()
# Out:
# array([2013, 2015, 2014, 2016], dtype=int64)

# %%
sales['Month'].unique()
# Out:
# array(['November', 'March', 'May', 'February', 'July', 'August',
#        'September', 'January', 'December', 'June', 'October', 'April'],
#       dtype=object)

# %%
sales.rename(columns={'Customer_Gender':'Gender'})
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26  November  2013            19           Youth (<25)
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 2     2014-03-23   23     March  2014            49        Adults (35-64)
# 3     2016-03-23   23     March  2016            49        Adults (35-64)
# 4     2014-05-15   15       May  2014            47        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 7638  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7639  2016-05-03    3       May  2016            29  Young Adults (25-34)
# 7640  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7641  2014-06-07    7      June  2014            29  Young Adults (25-34)
# 7642  2016-06-07    7      June  2016            29  Young Adults (25-34)
#
#      Gender         Country             State Product_Category  \
# ...

# %%
sales[pd.isnull(sales.Unit_Cost)]
# Out:
#             Date  Day Month  Year  Customer_Age             Age_Group  \
# 7642  2016-06-07    7  June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country    State Product_Category  \
# 7642               F  United Kingdom  England      Accessories
#
#            Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 7642  Bottles and Cages  Water Bottle - 30 o             NaN        NaN
#
#       Unit_Price  Profit  Cost  Revenue
# 7642         NaN     NaN   NaN      NaN

# %%
sales.loc[sales.Unit_Cost.isnull()]
# Out:
#             Date  Day Month  Year  Customer_Age             Age_Group  \
# 7642  2016-06-07    7  June  2016            29  Young Adults (25-34)
#
#      Customer_Gender         Country    State Product_Category  \
# 7642               F  United Kingdom  England      Accessories
#
#            Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 7642  Bottles and Cages  Water Bottle - 30 o             NaN        NaN
#
#       Unit_Price  Profit  Cost  Revenue
# 7642         NaN     NaN   NaN      NaN

# %%
sales[sales.Customer_Age.isin([19])]
# Out:
#             Date  Day      Month  Year  Customer_Age    Age_Group  \
# 0     2013-11-26   26   November  2013            19  Youth (<25)
# 1     2015-11-26   26   November  2015            19  Youth (<25)
# 62    2013-09-25   25  September  2013            19  Youth (<25)
# 63    2015-09-25   25  September  2015            19  Youth (<25)
# 362   2013-09-08    8  September  2013            19  Youth (<25)
# ...          ...  ...        ...   ...           ...          ...
# 7553  2016-05-30   30        May  2016            19  Youth (<25)
# 7554  2014-06-06    6       June  2014            19  Youth (<25)
# 7555  2014-06-06    6       June  2014            19  Youth (<25)
# 7556  2016-06-06    6       June  2016            19  Youth (<25)
# 7557  2016-06-06    6       June  2016            19  Youth (<25)
#
#      Customer_Gender        Country             State Product_Category  \
# 0                  M         Canada  British Columbia      Accessories
# ...

# %%
sales.loc[sales.Country=='Canada']
# Out:
#             Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26   November  2013            19           Youth (<25)
# 1     2015-11-26   26   November  2015            19           Youth (<25)
# 14    2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15    2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16    2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...          ...  ...        ...   ...           ...                   ...
# 7315  2016-02-10   10   February  2016            55        Adults (35-64)
# 7316  2014-02-21   21   February  2014            55        Adults (35-64)
# 7317  2016-02-21   21   February  2016            55        Adults (35-64)
# 7318  2014-02-23   23   February  2014            55        Adults (35-64)
# 7319  2016-02-23   23   February  2016            55        Adults (35-64)
#
#      Customer_Gender Country             State Product_Category  \
# ...

# %%
sales.loc[(sales.Month=='November') & (sales.Year==2015)]
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 37    2015-11-11   11  November  2015            34  Young Adults (25-34)
# 47    2015-11-17   17  November  2015            29  Young Adults (25-34)
# 65    2015-11-26   26  November  2015            26  Young Adults (25-34)
# 89    2015-11-06    6  November  2015            46        Adults (35-64)
# ...          ...  ...       ...   ...           ...                   ...
# 7323  2015-11-01    1  November  2015            55        Adults (35-64)
# 7460  2015-11-15   15  November  2015            28  Young Adults (25-34)
# 7461  2015-11-15   15  November  2015            28  Young Adults (25-34)
# 7616  2015-11-07    7  November  2015            29  Young Adults (25-34)
# 7617  2015-11-07    7  November  2015            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales.loc[(sales.Month=='November') | (sales.Year==2015)]
# Out:
#             Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0     2013-11-26   26  November  2013            19           Youth (<25)
# 1     2015-11-26   26  November  2015            19           Youth (<25)
# 11    2015-07-30   30      July  2015            32  Young Adults (25-34)
# 13    2015-07-15   15      July  2015            34  Young Adults (25-34)
# 15    2015-08-02    2    August  2015            29  Young Adults (25-34)
# ...          ...  ...       ...   ...           ...                   ...
# 7613  2015-10-28   28   October  2015            29  Young Adults (25-34)
# 7614  2013-11-07    7  November  2013            29  Young Adults (25-34)
# 7615  2013-11-07    7  November  2013            29  Young Adults (25-34)
# 7616  2015-11-07    7  November  2015            29  Young Adults (25-34)
# 7617  2015-11-07    7  November  2015            29  Young Adults (25-34)
#
#      Customer_Gender         Country             State Product_Category  \
# ...
